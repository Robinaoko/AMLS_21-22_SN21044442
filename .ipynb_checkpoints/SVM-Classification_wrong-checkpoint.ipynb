# %%
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook
from sklearn import svm, metrics, datasets
from sklearn.utils import Bunch
from sklearn.model_selection import GridSearchCV, train_test_split

import skimage.io as io
from skimage.io import imread
from skimage.transform import resize

# %%
#dirpath = './images/tumor/IMAGE_0000.jpg'
img_io = io.imread( './images/tumor/IMAGE_0900.jpg')
print("img_io :",img_io .shape)
# Out:
# img_io : (512, 512, 3)

# %%
#io.imshow(img_io)

# %%
import skimage.io as io
data_dir= './image/'
str=data_dir + '/*.jpg'
image_data = io.ImageCollection(str)
print(len(image_data))
# Out:
# 3000

# %%
import numpy as np
import os
from pathlib import Path

import matplotlib.pyplot as plt
from keras.preprocessing import image

# %%
p = Path("images/")
dirs = p.glob("*")

image_data = []
   

for folder_dir in dirs:
    
    for img_path in folder_dir.glob("*.jpg"):
        img = image.load_img(img_path, target_size=(100,100))
        img_array = image.img_to_array(img)
        image_data.append(img_array)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

tumor_label=pd.read_csv('label.csv')
label = []
for i in range(3000):
    data = tumor_label['label'][i]
    if data == 'no_tumor':
         label.append(data)
    else :
         label.append('yes_tumor')

# %%
label[0 : 10 ]
# Out:
# ['yes_tumor',
#  'no_tumor',
#  'yes_tumor',
#  'yes_tumor',
#  'yes_tumor',
#  'yes_tumor',
#  'no_tumor',
#  'yes_tumor',
#  'yes_tumor',
#  'yes_tumor']

# %%
#X_train, X_test, y_train, y_test = train_test_split(image_data,label, test_size=0.3,random_state=109)

# %%
image_data = np.array(image_data, dtype='float32')/255.0
label = np.array(label)

print(image_data.shape, label.shape)
# Out:
# (3000, 100, 100, 3) (3000,)

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
plt.imshow(image_data[3])
plt.axis('off')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
M = image_data.shape[0]
image_data = image_data.reshape(M,-1)
print(image_data.shape)
print(label.shape)
# Out:
# (3000, 30000)
# (3000,)

# %%
from sklearn import svm

svm_classifier = svm.SVC(kernel='linear', C=1.0)
svm_classifier.fit(image_data, label)
ypred_sklearn = svm_classifier.predict(image_data)
svm_classifier.score(image_data,label)
# Out:
# 0.973
